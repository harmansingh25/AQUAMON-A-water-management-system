# %% [markdown]
# <a href="https://colab.research.google.com/github/harmansingh25/AQUAMON-A-water-management-system/blob/master/Copy_of_CF_Project_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
# first install python 3.6
# !sudo apt-get update -y
# !sudo apt-get install python3.6
# change alternatives
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.6 1
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1,009 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:10 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,669 kB]
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:12 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# ...

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 3 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.10   2         auto mode
#   1            /usr/bin/python3.10   2         manual mode
#   2            /usr/bin/python3.6    1         manual mode
#   3            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.6 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !python --version
# Out:
# Python 3.6.15

# %%
# install pip for new python 
# !sudo apt-get install python3.6-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !python get-pip.py
# upgrade pip
# !sudo apt install python3-pip
# !python -m pip install --upgrade pi
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python3.6-lib2to3
# The following NEW packages will be installed:
#   python3.6-distutils python3.6-lib2to3
# 0 upgraded, 2 newly installed, 0 to remove and 25 not upgraded.
# Need to get 308 kB of archives.
# After this operation, 1,232 kB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 python3.6-lib2to3 all 3.6.15-1+focal3 [122 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 python3.6-distutils all 3.6.15-1+focal3 [187 kB]
# Fetched 308 kB in 2s (154 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# ...

# %%
# !pip install -r /content/drive/MyDrive/CF/DANCER/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 147 kB 21.2 MB/s
# ...
#      |████████████████████████████████| 829 kB 63.7 MB/s
# ...
#      |████████████████████████████████| 965 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 303 kB 73.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 73.0 MB/s
# ...
#      |████████████████████████████████| 11.6 MB 69.2 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 73.9 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 72.4 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 68.5 MB/s
# ...
#      |████████████████████████████████| 2.2 MB 69.8 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 78.7 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 227 kB 62.1 MB/s
# ...
#      |████████████████████████████████| 509 kB 72.7 MB/s
# ...
#      |████████████████████████████████| 269 kB 76.8 MB/s
# ...

# %%
# !python -m pip install --index-url https://pypi.anaconda.org/intel/simple --extra-index-url https://pypi.org/simple mkl_fft
# Out:
# Looking in indexes: https://pypi.anaconda.org/intel/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.org/simple
# ...
#      |████████████████████████████████| 232 kB 12.4 MB/s
# ...
#      |████████████████████████████████| 6.1 MB 63.2 MB/s
# ...
#      |████████████████████████████████| 254.1 MB 11 kB/s
# ...
#      |████████████████████████████████| 11.2 MB 70.5 MB/s
# ...
#      |████████████████████████████████| 396 kB 58.7 MB/s
# ...
#      |████████████████████████████████| 432 kB 69.9 MB/s
# ...
#      |████████████████████████████████| 919 kB 61.5 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 60.8 MB/s
# ...
#      |████████████████████████████████| 254.4 MB 22 kB/s
# ...
#      |████████████████████████████████| 259.9 MB 56 kB/s
# ...
#      |████████████████████████████████| 259.9 MB 51 kB/s
# ...
#      |████████████████████████████████| 256.4 MB 65 kB/s
# ...
#      |████████████████████████████████| 256.0 MB 63 kB/s
# ...
#      |████████████████████████████████| 256.0 MB 57 kB/s
# ...

# %%
# !python -m pip install --i https://pypi.anaconda.org/intel/simple -extra-index-url https://pypi.org/simple mkl_random

# %%
# !python -m pip install mkl-service

# %%
# !pip install ipykernel --user

# %%
# %cd /content/drive/MyDrive/CF/DANCER/examples

# %%
# !python run_exp.py --task TART --mode MF_v --setting naive --lr 1e-2 --reg 1e-4
# Out:
# 2023-04-18 20:52:08 - data: simulation2
# 2023-04-18 20:52:08 - task: TART
# 2023-04-18 20:52:08 - model: mf_v, debiasing: naive
# conf : {'embedding_size': '32', 'loss_type': 'mse', 'batch_size': '512', 'learning_rate': 0.01, 'optimizer': 'adam', 'ns_type': 'time', 'l2_reg': 0.0001, 'task': 'TART'}
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# Simulated test: 150512 interactions whose items do not appear in the training set. And thus Nr. testset is 1318363.
# (#users : 610, #items : 9724, period_type : year, n_periods : 7)
# -*-*-*-* We use s_{uit} = v_u * v_i + b + b_u + b_i *-*-*-*-
# model will be saved into: ./checkpoint_dir/TART_simulation2_mf_v_naive
# epoch 1, time-consumin: 0.252452 s, train-loss: 564.258886, valid-loss: 14.811870,
# results on validset: {'mse': 0.4110473671133701, 'mae': 0.4622555060374983, 'acc': 0.3951033732317737}
# ...

# %%
# !python run_exp.py --task TART --mode TMF_v --setting naive --lr 1e-2 --reg 1e-4
# Out:
# 2023-04-18 20:53:49 - data: simulation2
# 2023-04-18 20:53:49 - task: TART
# 2023-04-18 20:53:49 - model: tmf_v, debiasing: naive
# conf : {'embedding_size': '32', 'loss_type': 'mse', 'batch_size': '512', 'learning_rate': 0.01, 'optimizer': 'adam', 'ns_type': 'time', 'l2_reg': 0.0001, 'task': 'TART'}
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# Simulated test: 150512 interactions whose items do not appear in the training set. And thus Nr. testset is 1318363.
# (#users : 610, #items : 9724, period_type : year, n_periods : 7)
# ********* Using TMF-variety: (v_u * v_i) + b + b_i + b_u + b_T **********
# model will be saved into: ./checkpoint_dir/TART_simulation2_tmf_v_naive
# epoch 1, time-consumin: 0.284642 s, train-loss: 533.786821, valid-loss: 19.237028,
# ...

# %%
# !python run_exp.py --task TART --mode MF_v --setting StaticIps --lr 1e-2 --reg 1.0
# Out:
# 2023-04-18 20:54:43 - data: simulation2
# 2023-04-18 20:54:43 - task: TART
# 2023-04-18 20:54:43 - model: mf_v, debiasing: ips
# conf : {'embedding_size': '32', 'loss_type': 'mse', 'batch_size': '512', 'learning_rate': 0.01, 'optimizer': 'adam', 'ns_type': 'time', 'l2_reg': 1.0, 'task': 'TART'}
# !!!!! Estimate and Replace the propensities with pop_i. Done !!!!!
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# Simulated test: 150512 interactions whose items do not appear in the training set. And thus Nr. testset is 1318363.
# (#users : 610, #items : 9724, period_type : year, n_periods : 7)
# -*-*-*-* We use s_{uit} = v_u * v_i + b + b_u + b_i *-*-*-*-
# model will be saved into: ./checkpoint_dir/TART_simulation2_mf_v_ips
# epoch 1, time-consumin: 0.296053 s, train-loss: 4895763.769029, valid-loss: 132876.155889,
# ...

# %%
# !python run_exp.py --task TART --mode TMF_v --setting StaticIps --lr 1e-3 --reg 1e-1
# Out:
# 2023-04-18 21:03:26 - data: simulation2
# 2023-04-18 21:03:26 - task: TART
# 2023-04-18 21:03:26 - model: tmf_v, debiasing: ips
# conf : {'embedding_size': '32', 'loss_type': 'mse', 'batch_size': '512', 'learning_rate': 0.001, 'optimizer': 'adam', 'ns_type': 'time', 'l2_reg': 0.1, 'task': 'TART'}
# !!!!! Estimate and Replace the propensities with pop_i. Done !!!!!
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# Simulated test: 150512 interactions whose items do not appear in the training set. And thus Nr. testset is 1318363.
# (#users : 610, #items : 9724, period_type : year, n_periods : 7)
# ********* Using TMF-variety: (v_u * v_i) + b + b_i + b_u + b_T **********
# model will be saved into: ./checkpoint_dir/TART_simulation2_tmf_v_ips
# epoch 1, time-consumin: 0.302223 s, train-loss: 13901197.945426, valid-loss: 3001960.494546,
# ...

# %%
# !python run_exp.py --task TART --mode MF_v --setting DANCER --lr 1e-4 --reg 1e-3
# Out:
# 2023-04-18 20:57:17 - data: simulation2
# 2023-04-18 20:57:17 - task: TART
# 2023-04-18 20:57:17 - model: mf_v, debiasing: ips
# conf : {'embedding_size': '32', 'loss_type': 'mse', 'batch_size': '512', 'learning_rate': 0.0001, 'optimizer': 'adam', 'ns_type': 'time', 'l2_reg': 0.001, 'task': 'TART'}
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# Simulated test: 150512 interactions whose items do not appear in the training set. And thus Nr. testset is 1318363.
# (#users : 610, #items : 9724, period_type : year, n_periods : 7)
# -*-*-*-* We use s_{uit} = v_u * v_i + b + b_u + b_i *-*-*-*-
# model will be saved into: ./checkpoint_dir/TART_simulation2_mf_v_ips
# epoch 1, time-consumin: 0.412883 s, train-loss: 84482.083141, valid-loss: 20367.667983,
# ...

# %%
# !python run_exp.py --task TART --mode TMF_v --setting DANCER --lr 1e-4 --reg 1e-3
# Out:
# 2023-04-18 21:00:26 - data: simulation2
# 2023-04-18 21:00:26 - task: TART
# 2023-04-18 21:00:26 - model: tmf_v, debiasing: ips
# conf : {'embedding_size': '32', 'loss_type': 'mse', 'batch_size': '512', 'learning_rate': 0.0001, 'optimizer': 'adam', 'ns_type': 'time', 'l2_reg': 0.001, 'task': 'TART'}
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# ---------- Using Bins:  [0, 2, 4, 7, 10, 14, 20] ----------
# Simulated test: 150512 interactions whose items do not appear in the training set. And thus Nr. testset is 1318363.
# (#users : 610, #items : 9724, period_type : year, n_periods : 7)
# ********* Using TMF-variety: (v_u * v_i) + b + b_i + b_u + b_T **********
# model will be saved into: ./checkpoint_dir/TART_simulation2_tmf_v_ips
# epoch 1, time-consumin: 0.304481 s, train-loss: 98330.485883, valid-loss: 23461.486733,
# ...
